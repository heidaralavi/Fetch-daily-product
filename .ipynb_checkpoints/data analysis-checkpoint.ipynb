# %%
import pandas as pd
import numpy as np
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt

# %%
#importing data as dataframe
f='final_data.xlsx'
#f='/content/Fetch-daily-product/final_data.xlsx'
df= pd.read_excel(f,index_col=0)

# %%
df
# Out:
#            date       jdate  M+L+E(ton/day)  H(ton/day)  A(ton/day)  \
# 0    2019-03-21  1398/01/01           11131      860.78     12131.0
# 1    2019-03-22  1398/01/02           11514      789.73     12385.3
# 2    2019-03-23  1398/01/03           11849      854.57     12415.0
# 3    2019-03-24  1398/01/04           11722      862.67     12278.4
# 4    2019-03-25  1398/01/05            9127      585.07      9948.0
# ...         ...         ...             ...         ...         ...
# 1079 2022-03-04  1400/12/13           13151      819.96     14243.0
# 1080 2022-03-05  1400/12/14           13069      755.44     13928.2
# 1081 2022-03-06  1400/12/15           13089      265.12     13950.7
# 1082 2022-03-07  1400/12/16           13148      480.42     13935.3
# 1083 2022-03-08  1400/12/17           13094      981.95     13997.7
#
#       G(ton/day)
# 0         551.00
# 1         543.00
# 2         530.00
# 3         524.00
# 4         385.00
# ...          ...
# 1079      164.00
# 1080      156.00
# 1081      162.00
# 1082      154.00
# 1083      167.06
#
# [1084 rows x 6 columns]

# %%
#see inside of dataframe
df.describe(include='all')
# Out:
# C:\Users\H03C7~1.ALA\AppData\Local\Temp/ipykernel_14604/403188952.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#                        date       jdate  M+L+E(ton/day)   H(ton/day)  \
# count                  1084        1084     1084.000000  1084.000000
# unique                 1084        1084             NaN          NaN
# top     2019-03-21 00:00:00  1398/01/01             NaN          NaN
# freq                      1           1             NaN          NaN
# first   2019-03-21 00:00:00         NaN             NaN          NaN
# last    2022-03-08 00:00:00         NaN             NaN          NaN
# mean                    NaN         NaN    10116.183579   654.032518
# std                     NaN         NaN     3809.979111   358.062252
# min                     NaN         NaN        0.000000     0.000000
# 25%                     NaN         NaN    10543.000000   409.905000
# 50%                     NaN         NaN    11630.000000   748.440000
# 75%                     NaN         NaN    12064.000000   931.465000
# max                     NaN         NaN    13965.000000  1485.540000
#
#           A(ton/day)   G(ton/day)
# count    1084.000000  1084.000000
# unique           NaN          NaN
# top              NaN          NaN
# freq             NaN          NaN
# first            NaN          NaN
# last             NaN          NaN
# mean    10940.533072   414.232574
# std      4120.150555   269.909104
# min         0.000000     0.000000
# 25%     11445.425000   166.000000
# 50%     12686.885000   471.020000
# 75%     13101.112500   640.250000
# max     17675.000000   950.030000

# %%
#only production over 10000 ton/day analysed
df=df[df['M+L+E(ton/day)'] > 10000]

#H and G must be > 0
df=df[df['H(ton/day)'] > 0]
df=df[df['G(ton/day)'] > 0]

# %%
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.plot(df['date'],df['M+L+E(ton/day)'],)
ax.set_xlabel('Date')
ax.set_ylabel('Total Production per day (ton)')
# Out:
# Text(0, 0.5, 'Total Production per day (ton)')

# %%
#cleaning data by IsolationForest
from sklearn.ensemble import IsolationForest
data=df.iloc[:,2:].values
iso = IsolationForest()
yhat = iso.fit_predict(data)

# %%
# select all rows that are not outliers
mask = yhat != -1
df=df[mask]

# %%
df.reset_index(drop=True , inplace=True)

# %%
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.plot(df['date'],df['M+L+E(ton/day)'],)
ax.set_xlabel('Date')
ax.set_ylabel('Total Production per day (ton)')
# Out:
# Text(0, 0.5, 'Total Production per day (ton)')

# %%
df.describe()
# Out:
#        M+L+E(ton/day)   H(ton/day)    A(ton/day)  G(ton/day)
# count      688.000000   688.000000    688.000000  688.000000
# mean     11908.508721   801.745610  12871.525349  506.306424
# std        604.176707   235.847831    519.629618  220.269995
# min      10344.000000   132.620000  11406.120000  101.000000
# 25%      11529.750000   652.077500  12562.425000  335.255000
# 50%      11807.000000   850.490000  12888.350000  527.500000
# 75%      12174.750000   969.557500  13178.090000  685.970000
# max      13313.000000  1316.950000  14299.000000  903.000000

# %%
#calculating landa and H/A
final_df=df.copy()
landa=(df['A(ton/day)']-df['G(ton/day)']-df['H(ton/day)'])/df['M+L+E(ton/day)']
HA=df['H(ton/day)']/df['A(ton/day)']
GA=df['G(ton/day)']/df['A(ton/day)']
final_df['landa']= landa
final_df['H/A']=HA
final_df['G/A']=GA

# %%
final_df
# Out:
#           date       jdate  M+L+E(ton/day)  H(ton/day)  A(ton/day)  \
# 0   2019-03-21  1398/01/01           11131      860.78     12131.0
# 1   2019-03-22  1398/01/02           11514      789.73     12385.3
# 2   2019-03-23  1398/01/03           11849      854.57     12415.0
# 3   2019-03-24  1398/01/04           11722      862.67     12278.4
# 4   2019-03-26  1398/01/06           11907      840.19     12961.5
# ..         ...         ...             ...         ...         ...
# 683 2022-02-04  1400/11/15           12815      804.29     13742.0
# 684 2022-03-03  1400/12/12           12849     1021.63     13931.5
# 685 2022-03-04  1400/12/13           13151      819.96     14243.0
# 686 2022-03-05  1400/12/14           13069      755.44     13928.2
# 687 2022-03-08  1400/12/17           13094      981.95     13997.7
#
#      G(ton/day)     landa       H/A       G/A
# 0        551.00  0.963006  0.070957  0.045421
# 1        543.00  0.959924  0.063763  0.043842
# 2        530.00  0.930917  0.068834  0.042690
# 3        524.00  0.929170  0.070259  0.042677
# 4        481.00  0.977602  0.064822  0.037110
# ..          ...       ...       ...       ...
# 683      186.00  0.995061  0.058528  0.013535
# 684      142.94  0.993613  0.073332  0.010260
# 685      164.00  1.008215  0.057569  0.011514
# 686      156.00  0.996003  0.054238  0.011200
# 687      167.06  0.981265  0.070151  0.011935
#
# [688 rows x 9 columns]

# %%
kde = gaussian_kde(final_df.landa, bw_method=None, weights=None)

a={}
for item in np.linspace(0.8,1.2,100000):
    a[item]=kde.evaluate(item)
max_value = max(a, key=a.get)
max_value
# Out:
# 0.9582935829358293

# %%
fig , ax = plt.subplots(figsize=(11,5),dpi=200)
final_df.landa.plot(kind='kde', ax=ax)
final_df.landa.plot(kind='hist', ax=ax, secondary_y=True,alpha=0.5,bins=50,color='red')
ax.set_xlabel('Date')
ax.set_ylabel('KDE (landa)')
xlabels=ax.get_xticks().round(decimals=4)
xlabels = np.append(xlabels,np.array(max_value).round(decimals=5))
ax.set_xticklabels(xlabels, rotation=45, ha='right')
ax.set_xticks(xlabels)
ax.axvline(max_value)
plt.show()
# Out:
# C:\Users\H03C7~1.ALA\AppData\Local\Temp/ipykernel_14604/935330836.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xlabels, rotation=45, ha='right')

# %%
import datetime as dt
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.plot(final_df['date'],final_df['H/A'],)
#ax.plot(h_per_a_df['date'],h_per_a_df['landa'],)
ax.set_xlabel('Date')
ax.set_ylabel('H/A')
ax.axvline(dt.datetime(2019,8, 23),c='red',ls='--')
ax.axvline(dt.datetime(2019,9, 22),c='red',ls='--')
ax.axvline(dt.datetime(2021,6, 25),c='green',ls='-.')
ax.axvline(dt.datetime(2021,5, 28),c='green',ls='-.')

# %%
import datetime as dt
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.plot(final_df['date'],final_df['G/A'],)
#ax.plot(h_per_a_df['date'],h_per_a_df['landa'],)
ax.set_xlabel('Date')
ax.set_ylabel('G/A')
ax.axvline(dt.datetime(2019,8, 23),c='red',ls='--')
ax.axvline(dt.datetime(2019,9, 22),c='red',ls='--')
ax.axvline(dt.datetime(2021,6, 25),c='green',ls='-.')
ax.axvline(dt.datetime(2021,5, 28),c='green',ls='-.')

# %%
x,y=final_df['landa'],final_df['H/A']
m, b = np.polyfit(x, y, 1)

# %%
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.scatter(final_df['landa'],final_df['H/A'],)
ax.plot(x,m*x+b , c='red')
ax.set_xlabel('landa')
ax.set_ylabel('H/A')
# Out:
# Text(0, 0.5, 'H/A')

# %%
x,y=final_df['landa'],final_df['G/A']
m, b = np.polyfit(x, y, 1)

# %%
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.scatter(final_df['landa'],final_df['G/A'],)
ax.plot(x,m*x+b , c='red')
ax.set_xlabel('landa')
ax.set_ylabel('G/A')
# Out:
# Text(0, 0.5, 'G/A')

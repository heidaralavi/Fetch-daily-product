# %% [markdown]
# <a href="https://colab.research.google.com/github/heidaralavi/Fetch-daily-product/blob/main/compairing%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!git clone https://github.com/heidaralavi/Fetch-daily-product.git

# %%
import pandas as pd
import numpy as np
from scipy.stats import gaussian_kde

# %%
f='Daily production98-1400.xlsx'
#f='/content/Fetch-daily-product/Daily production98-1400.xlsx'
production_df = pd.DataFrame()
xl = pd.ExcelFile(f)
sheet_names=xl.sheet_names
for sheet_name in sheet_names:
    df_temp= pd.read_excel(f, sheet_name=sheet_name )
    production_df= production_df.append(df_temp,ignore_index = True)
        
production_df
# Out:
#       shamsidate  daily_production
# 0       13980101             11131
# 1       13980102             11514
# 2       13980103             11849
# 3       13980104             11722
# 4       13980105              9127
# ...          ...               ...
# 1079    14001213             13151
# 1080    14001214             13069
# 1081    14001215             13089
# 1082    14001216             13148
# 1083    14001217             13094
#
# [1084 rows x 2 columns]

# %%
temp_arr=[]
for item in production_df.iloc[:,0].values:
  temp=(str(item))
  temp = temp[:4]+'/'+temp[4:6]+'/'+temp[6:]
  temp_arr.append(temp)

production_df.insert(0,'jdate' ,temp_arr)
production_df.drop(columns='shamsidate',inplace=True)
production_df
# Out:
#            jdate  daily_production
# 0     1398/01/01             11131
# 1     1398/01/02             11514
# 2     1398/01/03             11849
# 3     1398/01/04             11722
# 4     1398/01/05              9127
# ...          ...               ...
# 1079  1400/12/13             13151
# 1080  1400/12/14             13069
# 1081  1400/12/15             13089
# 1082  1400/12/16             13148
# 1083  1400/12/17             13094
#
# [1084 rows x 2 columns]

# %%
f='final_data.xlsx'
#f='/content/Fetch-daily-product/final_data.xlsx'
final_df= pd.read_excel(f,index_col=0)

# %%
final_df
# Out:
#            date       jdate  M+L+E(ton/day)  H(ton/day)  A(ton/day)  \
# 0    2019-03-21  1398/01/01           11131      860.78     12131.0
# 1    2019-03-22  1398/01/02           11514      789.73     12385.3
# 2    2019-03-23  1398/01/03           11849      854.57     12415.0
# 3    2019-03-24  1398/01/04           11722      862.67     12278.4
# 4    2019-03-25  1398/01/05            9127      585.07      9948.0
# ...         ...         ...             ...         ...         ...
# 1079 2022-03-04  1400/12/13           13151      819.96     14243.0
# 1080 2022-03-05  1400/12/14           13069      755.44     13928.2
# 1081 2022-03-06  1400/12/15           13089      265.12     13950.7
# 1082 2022-03-07  1400/12/16           13148      480.42     13935.3
# 1083 2022-03-08  1400/12/17           13094      981.95     13997.7
#
#       G(ton/day)
# 0         551.00
# 1         543.00
# 2         530.00
# 3         524.00
# 4         385.00
# ...          ...
# 1079      164.00
# 1080      156.00
# 1081      162.00
# 1082      154.00
# 1083      167.06
#
# [1084 rows x 6 columns]

# %%
merged_df = pd.merge(final_df[['jdate','M+L+E(ton/day)']], production_df[['jdate','daily_production']],
                     on=['jdate'], how='outer')

# %%
merged_df
# Out:
#            jdate  M+L+E(ton/day)  daily_production
# 0     1398/01/01           11131             11131
# 1     1398/01/02           11514             11514
# 2     1398/01/03           11849             11849
# 3     1398/01/04           11722             11722
# 4     1398/01/05            9127              9127
# ...          ...             ...               ...
# 1079  1400/12/13           13151             13151
# 1080  1400/12/14           13069             13069
# 1081  1400/12/15           13089             13089
# 1082  1400/12/16           13148             13148
# 1083  1400/12/17           13094             13094
#
# [1084 rows x 3 columns]

# %%
merged_df.insert(3,'difference',merged_df['M+L+E(ton/day)']-merged_df['daily_production'])

# %%
merged_df[merged_df['difference'] != 0]
# Out:
#            jdate  M+L+E(ton/day)  daily_production  difference
# 92    1398/03/31            6193             14373       -8180
# 185   1398/06/31               0             10847      -10847
# 275   1398/09/30           11382             11204         178
# 364   1398/12/29           11955             12021         -66
# 550   1399/06/31            9510              9610        -100
# 709   1399/12/09           11211             11111         100
# 715   1399/12/15           11447             15486       -4039
# 832   1400/04/09           11152             11088          64
# 896   1400/06/11           12772             12662         110
# 1006  1400/09/30           13277             13270           7

# %%
mask=merged_df[merged_df['difference'] != 0]['jdate'].values

# %%
mask
# Out:
# array(['1398/03/31', '1398/06/31', '1398/09/30', '1398/12/29',
#        '1399/06/31', '1399/12/09', '1399/12/15', '1400/04/09',
#        '1400/06/11', '1400/09/30'], dtype=object)

# %%
final_df=final_df[final_df.jdate.isin(mask)==False].reset_index(drop=True)

# %%
final_df.describe(include='all')
# Out:
# C:\Users\H03C7~1.ALA\AppData\Local\Temp/ipykernel_4064/742465262.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   final_df.describe(include='all')
#                        date       jdate  M+L+E(ton/day)   H(ton/day)  \
# count                  1074        1074     1074.000000  1074.000000
# unique                 1074        1074             NaN          NaN
# top     2019-03-21 00:00:00  1398/01/01             NaN          NaN
# freq                      1           1             NaN          NaN
# first   2019-03-21 00:00:00         NaN             NaN          NaN
# last    2022-03-08 00:00:00         NaN             NaN          NaN
# mean                    NaN         NaN    10118.290503   654.334562
# std                     NaN         NaN     3810.099993   357.889681
# min                     NaN         NaN        0.000000     0.000000
# 25%                     NaN         NaN    10546.000000   410.210000
# 50%                     NaN         NaN    11634.000000   747.630000
# 75%                     NaN         NaN    12064.000000   932.590000
# max                     NaN         NaN    13965.000000  1485.540000
#
#           A(ton/day)   G(ton/day)
# count    1074.000000  1074.000000
# unique           NaN          NaN
# top              NaN          NaN
# freq             NaN          NaN
# first            NaN          NaN
# last             NaN          NaN
# mean    10941.819898   414.284060
# std      4120.189434   269.552909
# min         0.000000     0.000000
# 25%     11449.400000   166.007500
# 50%     12686.885000   471.510000
# 75%     13099.557500   640.750000
# max     17675.000000   950.030000

# %%
final_df=final_df[final_df['M+L+E(ton/day)'] > 10000]

# %%
import matplotlib.pyplot as plt
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.plot(final_df['date'],final_df['M+L+E(ton/day)'],)
ax.set_xlabel('Date')
ax.set_ylabel('Total Production per day (ton)')
# Out:
# Text(0, 0.5, 'Total Production per day (ton)')

# %%
landa_df=final_df.copy()
landa=(final_df['A(ton/day)']-final_df['G(ton/day)']-final_df['H(ton/day)'])/final_df['M+L+E(ton/day)']
landa_df['landa'] = landa

# %%
landa_df=landa_df[(landa_df['landa'] > 0.93) & (landa_df['landa'] < 1.05)]

# %%
kde = gaussian_kde(landa_df.landa, bw_method=None, weights=None)
kde.evaluate(item)
a={}

for item in np.linspace(0.8,1.2,100000):
    a[item]=kde.evaluate(item)
max_value = max(a, key=a.get)
max_value
# Out:
# 0.960509605096051

# %%
fig , ax = plt.subplots(figsize=(11,5),dpi=200)
landa_df.landa.plot(kind='kde', ax=ax)
landa_df.landa.plot(kind='hist', ax=ax, secondary_y=True,alpha=0.5,bins=50,color='red')
ax.set_xlabel('Date')
ax.set_ylabel('Total Production per day (ton)')
xlabels=ax.get_xticks().round(decimals=4)
xlabels = np.append(xlabels,np.array(max_value).round(decimals=5))
ax.set_xticklabels(xlabels, rotation=45, ha='right')
ax.set_xticks(xlabels)
ax.axvline(max_value)
plt.show()
print(type(xlabels))
# Out:
# C:\Users\H03C7~1.ALA\AppData\Local\Temp/ipykernel_4064/1516173184.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xlabels, rotation=45, ha='right')
# <class 'numpy.ndarray'>

# %%
a=np.where(landa_df.jdate == '1399/05/05')

# %%
b=np.where(landa_df.jdate == '1399/05/16')

# %%
print(a,b)
# Out:
# (array([328], dtype=int64),) (array([336], dtype=int64),)

# %%
landa_df[landa_df.values == '1399/05/05'].index
# Out:
# Int64Index([489], dtype='int64')

# %%
landa_df[a[0][0]:b[0][0]]
# Out:
#           date       jdate  M+L+E(ton/day)  H(ton/day)  A(ton/day)  \
# 489 2020-07-26  1399/05/05           10204      807.31    11304.87
# 490 2020-07-27  1399/05/06           11385     1012.86    12574.88
# 492 2020-07-29  1399/05/08           10041      681.31    11118.13
# 493 2020-07-30  1399/05/09           11634     1135.82    12741.12
# 494 2020-07-31  1399/05/10           11800      781.69    12908.06
# 495 2020-08-01  1399/05/11           11911     1157.57    13081.44
# 496 2020-08-02  1399/05/12           10089      835.91    10827.56
# 498 2020-08-04  1399/05/14           11011      816.73    12368.69
#
#      G(ton/day)     landa
# 489      617.00  0.968303
# 490      703.00  0.953801
# 492      594.97  0.980166
# 493      684.00  0.938740
# 494      682.00  0.969862
# 495      707.03  0.941721
# 496      572.00  0.933655
# 498      643.03  0.990730

# %%
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
landa_df[a[0][0]:b[0][0]].landa.plot(kind='kde', ax=ax)
landa_df[a[0][0]:b[0][0]].landa.plot(kind='hist', ax=ax, secondary_y=True,alpha=0.5,bins=50,color='red')
ax.set_xlabel('Date')
ax.set_ylabel('Total Production per day (ton)')
# Out:
# Text(0, 0.5, 'Total Production per day (ton)')

# %%
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.plot(final_df['date'],final_df['H(ton/day)'],)
ax.set_xlabel('Date')
ax.set_ylabel('Total Dust per day "H"(ton/day)')
# Out:
# Text(0, 0.5, 'Total Dust per day "H"(ton/day)')

# %%
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.plot(final_df['date'],final_df['G(ton/day)'],)
ax.set_xlabel('Date')
ax.set_ylabel('Total G ton per day (ton/day)')
# Out:
# Text(0, 0.5, 'Total G ton per day (ton/day)')

# %%
h_per_a_df=landa_df.copy()

# %%
h_per_a_df
# Out:
#            date       jdate  M+L+E(ton/day)  H(ton/day)  A(ton/day)  \
# 0    2019-03-21  1398/01/01           11131      860.78     12131.0
# 1    2019-03-22  1398/01/02           11514      789.73     12385.3
# 2    2019-03-23  1398/01/03           11849      854.57     12415.0
# 5    2019-03-26  1398/01/06           11907      840.19     12961.5
# 6    2019-03-27  1398/01/07           11003      455.05     11757.8
# ...         ...         ...             ...         ...         ...
# 1069 2022-03-04  1400/12/13           13151      819.96     14243.0
# 1070 2022-03-05  1400/12/14           13069      755.44     13928.2
# 1071 2022-03-06  1400/12/15           13089      265.12     13950.7
# 1072 2022-03-07  1400/12/16           13148      480.42     13935.3
# 1073 2022-03-08  1400/12/17           13094      981.95     13997.7
#
#       G(ton/day)     landa
# 0         551.00  0.963006
# 1         543.00  0.959924
# 2         530.00  0.930917
# 5         481.00  0.977602
# 6         428.00  0.988344
# ...          ...       ...
# 1069      164.00  1.008215
# 1070      156.00  0.996003
# 1071      162.00  1.033202
# 1072      154.00  1.011628
# 1073      167.06  0.981265
#
# [788 rows x 7 columns]

# %%
h_per_a_df['H/A']=h_per_a_df['H(ton/day)']/h_per_a_df['A(ton/day)']

# %%
h_per_a_df
# Out:
#            date       jdate  M+L+E(ton/day)  H(ton/day)  A(ton/day)  \
# 0    2019-03-21  1398/01/01           11131      860.78     12131.0
# 1    2019-03-22  1398/01/02           11514      789.73     12385.3
# 2    2019-03-23  1398/01/03           11849      854.57     12415.0
# 5    2019-03-26  1398/01/06           11907      840.19     12961.5
# 6    2019-03-27  1398/01/07           11003      455.05     11757.8
# ...         ...         ...             ...         ...         ...
# 1069 2022-03-04  1400/12/13           13151      819.96     14243.0
# 1070 2022-03-05  1400/12/14           13069      755.44     13928.2
# 1071 2022-03-06  1400/12/15           13089      265.12     13950.7
# 1072 2022-03-07  1400/12/16           13148      480.42     13935.3
# 1073 2022-03-08  1400/12/17           13094      981.95     13997.7
#
#       G(ton/day)     landa       H/A
# 0         551.00  0.963006  0.070957
# 1         543.00  0.959924  0.063763
# 2         530.00  0.930917  0.068834
# 5         481.00  0.977602  0.064822
# 6         428.00  0.988344  0.038702
# ...          ...       ...       ...
# 1069      164.00  1.008215  0.057569
# 1070      156.00  0.996003  0.054238
# 1071      162.00  1.033202  0.019004
# 1072      154.00  1.011628  0.034475
# 1073      167.06  0.981265  0.070151
#
# [788 rows x 8 columns]

# %%
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.plot(h_per_a_df['date'],h_per_a_df['H/A'],)
ax.plot(h_per_a_df['date'],h_per_a_df['landa'],)
ax.set_xlabel('Date')
ax.set_ylabel('H/A & Landa')
# Out:
# Text(0, 0.5, 'H/A & Landa')

# %%
x,y=h_per_a_df['landa'],h_per_a_df['H/A']
m, b = np.polyfit(x, y, 1)

# %%
fix , ax = plt.subplots(figsize=(11,5),dpi=200)
ax.scatter(h_per_a_df['landa'],h_per_a_df['H/A'],)
ax.plot(x,m*x+b , c='red')
ax.set_xlabel('landa')
ax.set_ylabel('H/A')
# Out:
# Text(0, 0.5, 'H/A')
